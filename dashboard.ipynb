# %%
from clickhouse_connect import get_client
import pandas as pd
from datetime import datetime, timedelta
import matplotlib.pyplot as plt

# Set up client
client = get_client(
    host='localhost',
    port=8123,
    username='default',
    password='mysecurepassword'
)

# Define time range
query = f"""
SELECT
    timestamp,
    price,
    volume
FROM price_ticks
ORDER BY timestamp ASC
"""

# Run query and convert to DataFrame
result = client.query(query)
df = pd.DataFrame(result.result_rows, columns=['timestamp', 'price', 'volume'])

# Show the first few rows
df.head()
# Out:
#             timestamp    price  volume
# 0 2025-05-19 02:01:53  2399.00  0.0401
# 1 2025-05-19 02:01:53  2398.99  0.0235
# 2 2025-05-19 02:01:53  2398.99  0.0294
# 3 2025-05-19 02:01:53  2399.00  0.0045
# 4 2025-05-19 02:01:53  2399.00  0.0996

# %%
# Plot price over time
plt.figure(figsize=(12, 6))
plt.plot(df['timestamp'], df['price'], label='Price')
plt.title('Price Over Last Hour')
plt.xlabel('Timestamp')
plt.ylabel('Price')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
len(df)  # Display the number of rows in the DataFrame
# Out:
# 380

# %%
# postgres_plot.py

import psycopg2
import pandas as pd
from datetime import datetime, timedelta, timezone
import matplotlib.pyplot as plt

# Connect to PostgreSQL
conn = psycopg2.connect(
    dbname='price_data',
    user='postgres',
    password='mypgpassword',
    host='localhost',
    port=5432
)
cursor = conn.cursor()

# Define time range
one_hour_ago = datetime.now(timezone.utc) - timedelta(hours=1)

# Fetch data
query = """
SELECT timestamp, price, volume
FROM price_ticks
WHERE timestamp >= %s
ORDER BY timestamp ASC
"""
cursor.execute(query, (one_hour_ago,))
rows = cursor.fetchall()

# Convert to DataFrame
df_pg = pd.DataFrame(rows, columns=['timestamp', 'price', 'volume'])
df_pg['timestamp'] = pd.to_datetime(df_pg['timestamp'])

# Plot price over time
plt.figure(figsize=(12, 6))
plt.plot(df_pg['timestamp'], df_pg['price'], label='Price', color='orange')
plt.title('PostgreSQL: Price Over Last Hour')
plt.xlabel('Timestamp')
plt.ylabel('Price')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
len(df_pg)
# Out:
# 49755

# %%
import boto3, os
from dotenv import load_dotenv

load_dotenv()

s3 = boto3.client('s3',
    region_name=os.getenv('AWS_REGION'),
    aws_access_key_id=os.getenv('AWS_ACCESS_KEY_ID'),
    aws_secret_access_key=os.getenv('AWS_SECRET_ACCESS_KEY')
)

# list all buckets
response = s3.list_buckets()
print("Your S3 buckets:", [b['Name'] for b in response['Buckets']])
# Out:
# Your S3 buckets: ['ticker-query-v1-etk', 'tickerdata-v1-etk']
